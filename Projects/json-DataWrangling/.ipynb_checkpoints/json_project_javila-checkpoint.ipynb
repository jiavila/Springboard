# %% [markdown]
# # 1. Find the 10 countries with most projects

# %% [markdown]
# ## Import & Inspect Data

# %%
import pandas as pd
import json
from pandas.io.json import json_normalize

json_data_df = pd.read_json('data/world_bank_projects.json')
print(json_data_df.columns)
json_data_df.head()
# Out:
# Index(['_id', 'approvalfy', 'board_approval_month', 'boardapprovaldate',
#        'borrower', 'closingdate', 'country_namecode', 'countrycode',
#        'countryname', 'countryshortname', 'docty', 'envassesmentcategorycode',
#        'grantamt', 'ibrdcommamt', 'id', 'idacommamt', 'impagency',
#        'lendinginstr', 'lendinginstrtype', 'lendprojectcost',
#        'majorsector_percent', 'mjsector_namecode', 'mjtheme',
#        'mjtheme_namecode', 'mjthemecode', 'prodline', 'prodlinetext',
#        'productlinetype', 'project_abstract', 'project_name', 'projectdocs',
#        'projectfinancialtype', 'projectstatusdisplay', 'regionname', 'sector',
#        'sector1', 'sector2', 'sector3', 'sector4', 'sector_namecode',
#        'sectorcode', 'source', 'status', 'supplementprojectflg', 'theme1',
#        'theme_namecode', 'themecode', 'totalamt', 'totalcommamt', 'url'],
#       dtype='object')
#                                     _id  approvalfy board_approval_month  \
# 0  {'$oid': '52b213b38594d8a2be17c780'}        1999             November
# 1  {'$oid': '52b213b38594d8a2be17c781'}        2015             November
# 2  {'$oid': '52b213b38594d8a2be17c782'}        2014             November
# 3  {'$oid': '52b213b38594d8a2be17c783'}        2014              October
# 4  {'$oid': '52b213b38594d8a2be17c784'}        2014              October
#
#       boardapprovaldate                                 borrower  \
# 0  2013-11-12T00:00:00Z  FEDERAL DEMOCRATIC REPUBLIC OF ETHIOPIA
# 1  2013-11-04T00:00:00Z                    GOVERNMENT OF TUNISIA
# 2  2013-11-01T00:00:00Z   MINISTRY OF FINANCE AND ECONOMIC DEVEL
# 3  2013-10-31T00:00:00Z   MIN. OF PLANNING AND INT'L COOPERATION
# 4  2013-10-31T00:00:00Z                      MINISTRY OF FINANCE
#
#             closingdate                              country_namecode  \
# 0  2018-07-07T00:00:00Z  Federal Democratic Republic of Ethiopia!$!ET
# 1                   NaN                      Republic of Tunisia!$!TN
# 2                   NaN                                   Tuvalu!$!TV
# 3                   NaN                        Republic of Yemen!$!RY
# 4  2019-04-30T00:00:00Z                       Kingdom of Lesotho!$!LS
#
#   countrycode                              countryname    countryshortname  \
# 0          ET  Federal Democratic Republic of Ethiopia            Ethiopia
# 1          TN                      Republic of Tunisia             Tunisia
# 2          TV                                   Tuvalu              Tuvalu
# 3          RY                        Republic of Yemen  Yemen, Republic of
# 4          LS                       Kingdom of Lesotho             Lesotho
#
#    ...   sectorcode source  status  supplementprojectflg  \
# 0  ...  ET,BS,ES,EP   IBRD  Active                     N
# 1  ...        BZ,BS   IBRD  Active                     N
# 2  ...           TI   IBRD  Active                     Y
# 3  ...           JB   IBRD  Active                     N
# 4  ...     FH,YW,YZ   IBRD  Active                     N
#
#                                               theme1  \
# 0      {'Percent': 100, 'Name': 'Education for all'}
# 1  {'Percent': 30, 'Name': 'Other economic manage...
# 2    {'Percent': 46, 'Name': 'Regional integration'}
# 3  {'Percent': 50, 'Name': 'Participation and civ...
# 4  {'Percent': 30, 'Name': 'Export development an...
#
#                                       theme_namecode    themecode   totalamt  \
# 0      [{'code': '65', 'name': 'Education for all'}]           65  130000000
# 1  [{'code': '24', 'name': 'Other economic manage...        54,24          0
# 2  [{'code': '47', 'name': 'Regional integration'...  52,81,25,47    6060000
# 3  [{'code': '57', 'name': 'Participation and civ...        59,57          0
# 4  [{'code': '45', 'name': 'Export development an...        41,45   13100000
#
#   totalcommamt                                                url
# 0    130000000  http://www.worldbank.org/projects/P129828/ethi...
# 1      4700000  http://www.worldbank.org/projects/P144674?lang=en
# 2      6060000  http://www.worldbank.org/projects/P145310?lang=en
# 3      1500000  http://www.worldbank.org/projects/P144665?lang=en
# 4     13100000  http://www.worldbank.org/projects/P144933/seco...
#
# [5 rows x 50 columns]

# %% [markdown]
# ## Count country names

# %%
# Check to see if there are only strings in each entry of 'project_name', indicating that there are no nested lists/dictionaries.
# This means that every entry in our DataFrame contains only one project.
count = 0
for idx, entry in enumerate(json_data_df['project_name']):
    if type(entry) != str:
        print('Entry ' + str(idx) + 'is not a string')
        count += 1

if count == 0:
    print("All entries in the 'project_name' column are strings.")
# Out:
# All entries in the 'project_name' column are strings.

# %%
# Since each entry in project_name is a string, then we can just count the number of times each country is mentioned and 
# list the top 10.
json_data_df['countryshortname'].value_counts().iloc[0:10]
# Out:
# Indonesia             19
# China                 19
# Vietnam               17
# India                 16
# Yemen, Republic of    13
# Morocco               12
# Bangladesh            12
# Nepal                 12
# Mozambique            11
# Africa                11
# Name: countryshortname, dtype: int64

# %% [markdown]
# # 2. Top 10 Major Project Themes

# %% [markdown]
# ## Open and reorder data

# %%
# Re-open json data as a list and normalize it
with open('data/world_bank_projects.json') as json_file:
    json_data_list = json.load(json_file)
json_data_norm = json_normalize(json_data_list, 'mjtheme_namecode', ['countryshortname', 'project_name'])
json_data_norm.columns = ['theme_code', 'theme_name', 'country', 'project_name']
json_data_norm.head()
# Out:
#   theme_code                             theme_name   country  \
# 0          8                      Human development  Ethiopia
# 1         11                                         Ethiopia
# 2          1                    Economic management   Tunisia
# 3          6  Social protection and risk management   Tunisia
# 4          5                  Trade and integration    Tuvalu
#
#                                         project_name
# 0  Ethiopia General Education Quality Improvement...
# 1  Ethiopia General Education Quality Improvement...
# 2          TN: DTF Social Protection Reforms Support
# 3          TN: DTF Social Protection Reforms Support
# 4  Tuvalu Aviation Investment Project - Additiona...

# %%
# Change theme_code column to type int
json_data_norm['theme_code'] = pd.to_numeric(json_data_norm['theme_code'])
json_data_norm.dtypes
# Out:
# theme_code       int64
# theme_name      object
# country         object
# project_name    object
# dtype: object

# %%
# Re-arrange the columns
cols_rearrange = ['country',  'project_name', 'theme_code', 'theme_name']
json_data_norm = json_data_norm[cols_rearrange]
json_data_norm.head()
# Out:
#     country                                       project_name  theme_code  \
# 0  Ethiopia  Ethiopia General Education Quality Improvement...           8
# 1  Ethiopia  Ethiopia General Education Quality Improvement...          11
# 2   Tunisia          TN: DTF Social Protection Reforms Support           1
# 3   Tunisia          TN: DTF Social Protection Reforms Support           6
# 4    Tuvalu  Tuvalu Aviation Investment Project - Additiona...           5
#
#                               theme_name
# 0                      Human development
# 1
# 2                    Economic management
# 3  Social protection and risk management
# 4                  Trade and integration

# %% [markdown]
# ## Count and show the top 10 major project themes
# Count the instances of the project and store in a proj_themes_top dataframe, create a dictionary where the key is the theme_code and the value is the theme_name, and then use the dictionary to create a new column in proj_themes_top with a map of our dictionary

# %%
# Count the theme_code values, since theme_name has missing values
proj_themes_top = json_data_norm['theme_code'].value_counts().iloc[0:10]
proj_themes_top = pd.DataFrame(proj_themes_top)  # turn Series into DataFrame
proj_themes_top = proj_themes_top.reset_index()  # reset the index
proj_themes_top.columns = ['theme_code', 'num_instances']  # rename the columns
proj_themes_top
# Out:
#    theme_code  num_instances
# 0          11            250
# 1          10            216
# 2           8            210
# 3           2            199
# 4           6            168
# 5           4            146
# 6           7            130
# 7           5             77
# 8           9             50
# 9           1             38

# %%
# Create a dictionary where the key is the theme_code and the value is the theme_name
theme_dict = {}
for code, name in json_data_norm[['theme_code', 'theme_name']].itertuples(index=False):
    if (name != '') & (not(int(code) in theme_dict)):  # only if name isn't emtpy and code isn't in theme_dict
        theme_dict[int(code)] = name  # convert key to int

# sort the dictionary
theme_dict = dict(sorted(theme_dict.items()))
theme_dict
# Out:
# {1: 'Economic management',
#  2: 'Public sector governance',
#  3: 'Rule of law',
#  4: 'Financial and private sector development',
#  5: 'Trade and integration',
#  6: 'Social protection and risk management',
#  7: 'Social dev/gender/inclusion',
#  8: 'Human development',
#  9: 'Urban development',
#  10: 'Rural development',
#  11: 'Environment and natural resources management'}

# %%
# Map a new column into proj_themes_top with our dictionary
proj_themes_top['theme_name'] = proj_themes_top['theme_code'].map(theme_dict)
proj_themes_top = proj_themes_top[['theme_code', 'theme_name', 'num_instances']]  # rearranged the columns
proj_themes_top
# Out:
#    theme_code                                    theme_name  num_instances
# 0          11  Environment and natural resources management            250
# 1          10                             Rural development            216
# 2           8                             Human development            210
# 3           2                      Public sector governance            199
# 4           6         Social protection and risk management            168
# 5           4      Financial and private sector development            146
# 6           7                   Social dev/gender/inclusion            130
# 7           5                         Trade and integration             77
# 8           9                             Urban development             50
# 9           1                           Economic management             38

# %% [markdown]
# # 3. Create a DataFrame with missing theme names filled in
# We'll just use the theme_dict dictionary we created in 2. and map the 'theme_name' column of json_data_norm with a filter only on empty instances

# %%
for idx, code, name in json_data_norm[['theme_code', 'theme_name']].itertuples(index=True):
    if name == '':
        json_data_norm.iloc[idx, -1] = theme_dict[code]
        
json_data_norm
# Out:
#                                country  \
# 0                             Ethiopia
# 1                             Ethiopia
# 2                              Tunisia
# 3                              Tunisia
# 4                               Tuvalu
# 5                               Tuvalu
# 6                               Tuvalu
# 7                               Tuvalu
# 8                   Yemen, Republic of
# 9                   Yemen, Republic of
# 10                             Lesotho
# 11                             Lesotho
# 12                               Kenya
# 13                               Kenya
# 14                               India
# 15                               India
# 16                               China
# 17                               China
# 18                               India
# 19                               India
# 20                             Morocco
# 21                             Morocco
# 22                             Morocco
# 23                         South Sudan
# 24                         South Sudan
# 25                               India
# 26                               India
# 27                               India
# 28                               India
# 29                               Ghana
# ...                                ...
# 1469                            Brazil
# 1470                  Papua New Guinea
# 1471                  Papua New Guinea
# 1472                  Papua New Guinea
# 1473                  Papua New Guinea
# 1474                             Nepal
# 1475                             Nepal
# 1476                West Bank and Gaza
# 1477                West Bank and Gaza
# 1478                          Pakistan
# 1479                          Pakistan
# 1480                        Bangladesh
# 1481                        Bangladesh
# 1482                             Nepal
# 1483                             Nepal
# 1484                           Jamaica
# 1485                           Jamaica
# 1486  Lao People's Democratic Republic
# 1487  Lao People's Democratic Republic
# 1488  Lao People's Democratic Republic
# 1489  Lao People's Democratic Republic
# 1490                            Guinea
# 1491                            Guinea
# 1492                         Indonesia
# 1493                         Indonesia
# 1494                         Indonesia
# 1495                             Kenya
# 1496                             Kenya
# 1497                             Kenya
# 1498                             Kenya
#
#                                            project_name  theme_code  \
# 0     Ethiopia General Education Quality Improvement...           8
# 1     Ethiopia General Education Quality Improvement...          11
# 2             TN: DTF Social Protection Reforms Support           1
# 3             TN: DTF Social Protection Reforms Support           6
# 4     Tuvalu Aviation Investment Project - Additiona...           5
# 5     Tuvalu Aviation Investment Project - Additiona...           2
# 6     Tuvalu Aviation Investment Project - Additiona...          11
# 7     Tuvalu Aviation Investment Project - Additiona...           6
# 8      Gov't and Civil Society Organization Partnership           7
# 9      Gov't and Civil Society Organization Partnership           7
# 10    Second Private Sector Competitiveness and Econ...           5
# 11    Second Private Sector Competitiveness and Econ...           4
# 12    Additional Financing for Cash Transfers for Or...           6
# 13    Additional Financing for Cash Transfers for Or...           6
# 14    National Highways Interconnectivity Improvemen...           2
# 15    National Highways Interconnectivity Improvemen...           4
# 16     China Renewable Energy Scale-Up Program Phase II          11
# 17     China Renewable Energy Scale-Up Program Phase II           8
# 18          Rajasthan Road Sector Modernization Project          10
# 19          Rajasthan Road Sector Modernization Project           7
# 20               MA Accountability and Transparency DPL           2
# 21               MA Accountability and Transparency DPL           2
# 22               MA Accountability and Transparency DPL           2
# 23    Southern Sudan Emergency Food Crisis Response ...          10
# 24    Southern Sudan Emergency Food Crisis Response ...           2
# 25                Uttarakhand Disaster Recovery Project          10
# 26                Uttarakhand Disaster Recovery Project           6
# 27                Uttarakhand Disaster Recovery Project           6
# 28                Uttarakhand Disaster Recovery Project          11
# 29                                  GH eTransform Ghana           4
# ...                                                 ...         ...
# 1469              RIO STATE DEVELOPMENT POLICY LOAN III           8
# 1470    Papua New Guinea Settlement Upgrading Programme           9
# 1471    Papua New Guinea Settlement Upgrading Programme           6
# 1472    Papua New Guinea Settlement Upgrading Programme           6
# 1473    Papua New Guinea Settlement Upgrading Programme           9
# 1474  Nepal PFM-MDTF Strengthening Civil Society Org...           2
# 1475  Nepal PFM-MDTF Strengthening Civil Society Org...           2
# 1476  Water Supply and Sanitation Improvements for W...          10
# 1477  Water Supply and Sanitation Improvements for W...          11
# 1478  Pakistan: Promoting Girls' Education in Baloch...           8
# 1479  Pakistan: Promoting Girls' Education in Baloch...           7
# 1480  Revision and Alignment of NAP with UNCCD 10-ye...          11
# 1481  Revision and Alignment of NAP with UNCCD 10-ye...           5
# 1482  Nepal: Pilot Project for Seismic School Safety...           6
# 1483  Nepal: Pilot Project for Seismic School Safety...           8
# 1484  Technological Scale Up for Youth-led Urban Orn...           4
# 1485  Technological Scale Up for Youth-led Urban Orn...           7
# 1486                Lao Eight Poverty Reduction Support           8
# 1487                Lao Eight Poverty Reduction Support           5
# 1488                Lao Eight Poverty Reduction Support           2
# 1489                Lao Eight Poverty Reduction Support           8
# 1490  Second Emergency Agricultural Productivity Sup...          10
# 1491  Second Emergency Agricultural Productivity Sup...           6
# 1492  Sustainable Management of Agricultural Researc...          10
# 1493  Sustainable Management of Agricultural Researc...          10
# 1494  Sustainable Management of Agricultural Researc...          10
# 1495  KENYA: NATIONAL URBAN TRANSPORT IMPROVEMENT PR...           9
# 1496  KENYA: NATIONAL URBAN TRANSPORT IMPROVEMENT PR...           8
# 1497  KENYA: NATIONAL URBAN TRANSPORT IMPROVEMENT PR...           5
# 1498  KENYA: NATIONAL URBAN TRANSPORT IMPROVEMENT PR...           4
#
#                                         theme_name
# 0                                Human development
# 1     Environment and natural resources management
# 2                              Economic management
# 3            Social protection and risk management
# 4                            Trade and integration
# 5                         Public sector governance
# 6     Environment and natural resources management
# 7            Social protection and risk management
# 8                      Social dev/gender/inclusion
# 9                      Social dev/gender/inclusion
# 10                           Trade and integration
# 11        Financial and private sector development
# 12           Social protection and risk management
# 13           Social protection and risk management
# 14                        Public sector governance
# 15        Financial and private sector development
# 16    Environment and natural resources management
# 17                               Human development
# 18                               Rural development
# 19                     Social dev/gender/inclusion
# 20                        Public sector governance
# 21                        Public sector governance
# 22                        Public sector governance
# 23                               Rural development
# 24                        Public sector governance
# 25                               Rural development
# 26           Social protection and risk management
# 27           Social protection and risk management
# 28    Environment and natural resources management
# 29        Financial and private sector development
# ...                                            ...
# 1469                             Human development
# 1470                             Urban development
# 1471         Social protection and risk management
# 1472         Social protection and risk management
# 1473                             Urban development
# 1474                      Public sector governance
# 1475                      Public sector governance
# 1476                             Rural development
# 1477  Environment and natural resources management
# 1478                             Human development
# 1479                   Social dev/gender/inclusion
# 1480  Environment and natural resources management
# 1481                         Trade and integration
# 1482         Social protection and risk management
# 1483                             Human development
# 1484      Financial and private sector development
# 1485                   Social dev/gender/inclusion
# 1486                             Human development
# 1487                         Trade and integration
# 1488                      Public sector governance
# 1489                             Human development
# 1490                             Rural development
# 1491         Social protection and risk management
# 1492                             Rural development
# 1493                             Rural development
# 1494                             Rural development
# 1495                             Urban development
# 1496                             Human development
# 1497                         Trade and integration
# 1498      Financial and private sector development
#
# [1499 rows x 4 columns]
